# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/FOUR_cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3)) 

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 291,466
# Trainable params: 291,466
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=5)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
x_train_cnn = x_train.reshape((x_train.shape[0], 32, 32, 3))
x_test_cnn = x_test.reshape((x_test.shape[0], 32, 32, 3))
x_val_cnn = x_val.reshape((x_val.shape[0],32,32,3))

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_cnn.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_cnn.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_cnn.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_cnn, y_train, epochs=50, use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 6s 38ms/step - loss: 2.3043 - accuracy: 0.1014 - val_loss: 2.3005 - val_accuracy: 0.1033
# Epoch 2/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.3000 - accuracy: 0.1053 - val_loss: 2.2997 - val_accuracy: 0.1384
# Epoch 3/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.2984 - accuracy: 0.1083 - val_loss: 2.2981 - val_accuracy: 0.1476
# Epoch 4/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.2964 - accuracy: 0.1129 - val_loss: 2.2958 - val_accuracy: 0.1482
# Epoch 5/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.2932 - accuracy: 0.1143 - val_loss: 2.2918 - val_accuracy: 0.1447
# Epoch 6/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.2878 - accuracy: 0.1196 - val_loss: 2.2849 - val_accuracy: 0.1501
# Epoch 7/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.2788 - accuracy: 0.1263 - val_loss: 2.2710 - val_accuracy: 0.1395
# Epoch 8/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.2657 - accuracy: 0.1306 - val_loss: 2.2566 - val_accuracy: 0.1555
# Epoch 9/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.2469 - accuracy: 0.1409 - val_loss: 2.2279 - val_accuracy: 0.1610
# Epoch 10/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.2268 - accuracy: 0.1487 - val_loss: 2.2029 - val_accuracy: 0.1886
# Epoch 11/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.2048 - accuracy: 0.1645 - val_loss: 2.1897 - val_accuracy: 0.1932
# Epoch 12/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1923 - accuracy: 0.1680 - val_loss: 2.1734 - val_accuracy: 0.1969
# Epoch 13/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1829 - accuracy: 0.1706 - val_loss: 2.1672 - val_accuracy: 0.2026
# Epoch 14/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1701 - accuracy: 0.1752 - val_loss: 2.1397 - val_accuracy: 0.1977
# Epoch 15/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1618 - accuracy: 0.1766 - val_loss: 2.1687 - val_accuracy: 0.1967
# Epoch 16/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1547 - accuracy: 0.1813 - val_loss: 2.1366 - val_accuracy: 0.2234
# Epoch 17/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1436 - accuracy: 0.1840 - val_loss: 2.1056 - val_accuracy: 0.2306
# Epoch 18/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1327 - accuracy: 0.1922 - val_loss: 2.0995 - val_accuracy: 0.2344
# Epoch 19/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1273 - accuracy: 0.1896 - val_loss: 2.1702 - val_accuracy: 0.2014
# Epoch 20/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1174 - accuracy: 0.1944 - val_loss: 2.0659 - val_accuracy: 0.2404
# Epoch 21/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.1112 - accuracy: 0.1924 - val_loss: 2.0604 - val_accuracy: 0.2298
# Epoch 22/50
# 79/79 [==============================] - 2s 31ms/step - loss: 2.1040 - accuracy: 0.2000 - val_loss: 2.0654 - val_accuracy: 0.2342
# Epoch 23/50
# 79/79 [==============================] - 2s 29ms/step - loss: 2.0915 - accuracy: 0.1990 - val_loss: 2.0786 - val_accuracy: 0.2240
# Epoch 24/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0786 - accuracy: 0.2020 - val_loss: 2.0181 - val_accuracy: 0.2430
# Epoch 25/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0659 - accuracy: 0.2019 - val_loss: 1.9940 - val_accuracy: 0.2496
# Epoch 26/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0552 - accuracy: 0.2068 - val_loss: 1.9867 - val_accuracy: 0.2526
# Epoch 27/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0441 - accuracy: 0.2094 - val_loss: 1.9625 - val_accuracy: 0.2546
# Epoch 28/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0251 - accuracy: 0.2123 - val_loss: 2.0156 - val_accuracy: 0.2323
# Epoch 29/50
# 79/79 [==============================] - 2s 30ms/step - loss: 2.0123 - accuracy: 0.2162 - val_loss: 1.9831 - val_accuracy: 0.2427
# Epoch 30/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9985 - accuracy: 0.2227 - val_loss: 2.0314 - val_accuracy: 0.2267
# Epoch 31/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9935 - accuracy: 0.2195 - val_loss: 1.9564 - val_accuracy: 0.2543
# Epoch 32/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9906 - accuracy: 0.2225 - val_loss: 1.9981 - val_accuracy: 0.2396
# Epoch 33/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9630 - accuracy: 0.2287 - val_loss: 1.9561 - val_accuracy: 0.2513
# Epoch 34/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9562 - accuracy: 0.2346 - val_loss: 1.8826 - val_accuracy: 0.2736
# Epoch 35/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9580 - accuracy: 0.2322 - val_loss: 1.8704 - val_accuracy: 0.2777
# Epoch 36/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9370 - accuracy: 0.2399 - val_loss: 1.8512 - val_accuracy: 0.2847
# Epoch 37/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9269 - accuracy: 0.2481 - val_loss: 1.8514 - val_accuracy: 0.2878
# Epoch 38/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9154 - accuracy: 0.2504 - val_loss: 1.8347 - val_accuracy: 0.2999
# Epoch 39/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9121 - accuracy: 0.2543 - val_loss: 1.8244 - val_accuracy: 0.3045
# Epoch 40/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.9073 - accuracy: 0.2567 - val_loss: 1.8086 - val_accuracy: 0.3178
# Epoch 41/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8984 - accuracy: 0.2657 - val_loss: 1.8015 - val_accuracy: 0.3237
# Epoch 42/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8791 - accuracy: 0.2689 - val_loss: 1.8486 - val_accuracy: 0.3149
# Epoch 43/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8822 - accuracy: 0.2729 - val_loss: 1.7889 - val_accuracy: 0.3331
# Epoch 44/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8706 - accuracy: 0.2793 - val_loss: 2.0282 - val_accuracy: 0.2691
# Epoch 45/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8802 - accuracy: 0.2776 - val_loss: 1.8561 - val_accuracy: 0.3076
# Epoch 46/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8548 - accuracy: 0.2854 - val_loss: 1.7779 - val_accuracy: 0.3490
# Epoch 47/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8574 - accuracy: 0.2866 - val_loss: 1.7638 - val_accuracy: 0.3518
# Epoch 48/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8309 - accuracy: 0.2925 - val_loss: 1.7578 - val_accuracy: 0.3513
# Epoch 49/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8367 - accuracy: 0.2983 - val_loss: 1.8542 - val_accuracy: 0.3252
# Epoch 50/50
# 79/79 [==============================] - 2s 30ms/step - loss: 1.8125 - accuracy: 0.3034 - val_loss: 1.8021 - val_accuracy: 0.3463

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:02.609547

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.356

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_cnn)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
