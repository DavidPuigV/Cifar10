# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/ONE_cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 197,002
# Trainable params: 197,002
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 197,002
# Trainable params: 197,002
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
x_train_cnn = x_train.reshape((x_train.shape[0], 32, 32, 3))
x_test_cnn = x_test.reshape((x_test.shape[0], 32, 32, 3))
x_val_cnn = x_val.reshape((x_val.shape[0],32,32,3))

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_cnn.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_cnn.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_cnn.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_cnn, y_train, epochs=20, use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 79/79 [==============================] - 6s 43ms/step - loss: 2.2439 - accuracy: 0.1473 - val_loss: 1.9381 - val_accuracy: 0.3201
# Epoch 2/200
# 79/79 [==============================] - 3s 35ms/step - loss: 1.9344 - accuracy: 0.2935 - val_loss: 1.6902 - val_accuracy: 0.4047
# Epoch 3/200
# 79/79 [==============================] - 3s 35ms/step - loss: 1.7468 - accuracy: 0.3569 - val_loss: 1.4929 - val_accuracy: 0.4678
# Epoch 4/200
# 79/79 [==============================] - 3s 35ms/step - loss: 1.6153 - accuracy: 0.3974 - val_loss: 1.3871 - val_accuracy: 0.5224
# Epoch 5/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.5207 - accuracy: 0.4358 - val_loss: 1.2960 - val_accuracy: 0.5450
# Epoch 6/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.4633 - accuracy: 0.4570 - val_loss: 1.2437 - val_accuracy: 0.5649
# Epoch 7/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.4094 - accuracy: 0.4833 - val_loss: 1.2232 - val_accuracy: 0.5761
# Epoch 8/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.3769 - accuracy: 0.4956 - val_loss: 1.1722 - val_accuracy: 0.5882
# Epoch 9/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.3502 - accuracy: 0.5045 - val_loss: 1.1306 - val_accuracy: 0.6034
# Epoch 10/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.3169 - accuracy: 0.5181 - val_loss: 1.1007 - val_accuracy: 0.6188
# Epoch 11/200
# 79/79 [==============================] - 3s 37ms/step - loss: 1.2934 - accuracy: 0.5271 - val_loss: 1.0811 - val_accuracy: 0.6233
# Epoch 12/200
# 79/79 [==============================] - 3s 37ms/step - loss: 1.2834 - accuracy: 0.5295 - val_loss: 1.0455 - val_accuracy: 0.6373
# Epoch 13/200
# 79/79 [==============================] - 3s 36ms/step - loss: 1.2331 - accuracy: 0.5517 - val_loss: 1.0385 - val_accuracy: 0.6388
# Epoch 14/200
200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6579 - accuracy: 0.7655 - val_loss: 0.6217 - val_accuracy: 0.7865
# Epoch 99/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6479 - accuracy: 0.7724 - val_loss: 0.6182 - val_accuracy: 0.7880
# Epoch 100/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6419 - accuracy: 0.7692 - val_loss: 0.6174 - val_accuracy: 0.7897
# Epoch 101/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6591 - accuracy: 0.7651 - val_loss: 0.6373 - val_accuracy: 0.7860
# Epoch 102/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6495 - accuracy: 0.7664 - val_loss: 0.6192 - val_accuracy: 0.7903
# Epoch 103/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6504 - accuracy: 0.7699 - val_loss: 0.6225 - val_accuracy: 0.7918
# Epoch 104/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6403 - accuracy: 0.7711 - val_loss: 0.6010 - val_accuracy: 0.7942
# Epoch 105/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6398 - accuracy: 0.7744 - val_loss: 0.6036 - val_accuracy: 0.7986
# Epoch 106/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6365 - accuracy: 0.7761 - val_loss: 0.6152 - val_accuracy: 0.7897
# Epoch 107/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6374 - accuracy: 0.7708 - val_loss: 0.6187 - val_accuracy: 0.7914
# Epoch 108/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6362 - accuracy: 0.7742 - val_loss: 0.6103 - val_accuracy: 0.7943
# Epoch 109/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6330 - accuracy: 0.7765 - val_loss: 0.5994 - val_accuracy: 0.7959
# Epoch 110/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6214 - accuracy: 0.7786 - val_loss: 0.6203 - val_accuracy: 0.7895
# Epoch 111/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6310 - accuracy: 0.7744 - val_loss: 0.5977 - val_accuracy: 0.7948
# Epoch 112/200
# 79/79 [==============================] - 3s 37ms/step - loss: 0.6250 - accuracy: 0.7758 - val_loss: 0.5854 - val_accuracy: 0.7999
# Epoch 113/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6184 - accuracy: 0.7774 - val_loss: 0.5924 - val_accuracy: 0.7972
# Epoch 114/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6318 - accuracy: 0.7753 - val_loss: 0.6048 - val_accuracy: 0.7977
# Epoch 115/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6338 - accuracy: 0.7746 - val_loss: 0.5893 - val_accuracy: 0.8017
# Epoch 116/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6205 - accuracy: 0.7764 - val_loss: 0.5857 - val_accuracy: 0.7995
# Epoch 117/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6155 - accuracy: 0.7828 - val_loss: 0.6046 - val_accuracy: 0.7950
# Epoch 118/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6273 - accuracy: 0.7725 - val_loss: 0.5966 - val_accuracy: 0.7974
# Epoch 119/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6227 - accuracy: 0.7784 - val_loss: 0.6062 - val_accuracy: 0.7929
# Epoch 120/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6121 - accuracy: 0.7827 - val_loss: 0.5986 - val_accuracy: 0.8005
# Epoch 121/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6202 - accuracy: 0.7765 - val_loss: 0.5933 - val_accuracy: 0.7967
# Epoch 122/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6176 - accuracy: 0.7790 - val_loss: 0.6082 - val_accuracy: 0.7956
# Epoch 123/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6089 - accuracy: 0.7827 - val_loss: 0.6015 - val_accuracy: 0.8008
# Epoch 124/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6112 - accuracy: 0.7829 - val_loss: 0.6199 - val_accuracy: 0.7925
# Epoch 125/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6174 - accuracy: 0.7772 - val_loss: 0.5846 - val_accuracy: 0.8014
# Epoch 126/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.6051 - accuracy: 0.7883 - val_loss: 0.5889 - val_accuracy: 0.8019
# Epoch 127/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6119 - accuracy: 0.7829 - val_loss: 0.5926 - val_accuracy: 0.7979
# Epoch 128/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6003 - accuracy: 0.7833 - val_loss: 0.6009 - val_accuracy: 0.7969
# Epoch 129/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6095 - accuracy: 0.7831 - val_loss: 0.6055 - val_accuracy: 0.7981
# Epoch 130/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5963 - accuracy: 0.7870 - val_loss: 0.5912 - val_accuracy: 0.8002
# Epoch 131/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5954 - accuracy: 0.7897 - val_loss: 0.5980 - val_accuracy: 0.7987
# Epoch 132/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6011 - accuracy: 0.7854 - val_loss: 0.5841 - val_accuracy: 0.8008
# Epoch 133/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5893 - accuracy: 0.7891 - val_loss: 0.5970 - val_accuracy: 0.7973
# Epoch 134/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5976 - accuracy: 0.7849 - val_loss: 0.5816 - val_accuracy: 0.8016
# Epoch 135/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6036 - accuracy: 0.7838 - val_loss: 0.6100 - val_accuracy: 0.8004
# Epoch 136/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5981 - accuracy: 0.7843 - val_loss: 0.5805 - val_accuracy: 0.8045
# Epoch 137/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5924 - accuracy: 0.7869 - val_loss: 0.5855 - val_accuracy: 0.8043
# Epoch 138/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5981 - accuracy: 0.7890 - val_loss: 0.5975 - val_accuracy: 0.7994
# Epoch 139/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5997 - accuracy: 0.7836 - val_loss: 0.6002 - val_accuracy: 0.8003
# Epoch 140/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5833 - accuracy: 0.7897 - val_loss: 0.6012 - val_accuracy: 0.8026
# Epoch 141/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5882 - accuracy: 0.7913 - val_loss: 0.5901 - val_accuracy: 0.8029
# Epoch 142/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5740 - accuracy: 0.7946 - val_loss: 0.5901 - val_accuracy: 0.8030
# Epoch 143/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5875 - accuracy: 0.7875 - val_loss: 0.5929 - val_accuracy: 0.8011
# Epoch 144/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.6086 - accuracy: 0.7841 - val_loss: 0.5842 - val_accuracy: 0.8044
# Epoch 145/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5830 - accuracy: 0.7903 - val_loss: 0.6011 - val_accuracy: 0.7957
# Epoch 146/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5908 - accuracy: 0.7876 - val_loss: 0.5921 - val_accuracy: 0.8022
# Epoch 147/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5815 - accuracy: 0.7933 - val_loss: 0.6081 - val_accuracy: 0.7958
# Epoch 148/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5797 - accuracy: 0.7896 - val_loss: 0.6003 - val_accuracy: 0.7985
# Epoch 149/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5884 - accuracy: 0.7886 - val_loss: 0.5894 - val_accuracy: 0.8037
# Epoch 150/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5714 - accuracy: 0.7943 - val_loss: 0.5930 - val_accuracy: 0.7991
# Epoch 151/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5852 - accuracy: 0.7876 - val_loss: 0.5843 - val_accuracy: 0.8030
# Epoch 152/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5888 - accuracy: 0.7904 - val_loss: 0.5866 - val_accuracy: 0.8044
# Epoch 153/200
# 79/79 [==============================] - 3s 37ms/step - loss: 0.5730 - accuracy: 0.7967 - val_loss: 0.5908 - val_accuracy: 0.8016
# Epoch 154/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5810 - accuracy: 0.7895 - val_loss: 0.5761 - val_accuracy: 0.8071
# Epoch 155/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5757 - accuracy: 0.7954 - val_loss: 0.5889 - val_accuracy: 0.8020
# Epoch 156/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5858 - accuracy: 0.7926 - val_loss: 0.5792 - val_accuracy: 0.8078
# Epoch 157/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5736 - accuracy: 0.7960 - val_loss: 0.6048 - val_accuracy: 0.7976
# Epoch 158/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5727 - accuracy: 0.7961 - val_loss: 0.5995 - val_accuracy: 0.8005
# Epoch 159/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5805 - accuracy: 0.7930 - val_loss: 0.5662 - val_accuracy: 0.8111
# Epoch 160/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5758 - accuracy: 0.7949 - val_loss: 0.5849 - val_accuracy: 0.8026
# Epoch 161/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5561 - accuracy: 0.8018 - val_loss: 0.5884 - val_accuracy: 0.8042
# Epoch 162/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5680 - accuracy: 0.7992 - val_loss: 0.6314 - val_accuracy: 0.7956
# Epoch 163/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5784 - accuracy: 0.7927 - val_loss: 0.5774 - val_accuracy: 0.8059
# Epoch 164/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5770 - accuracy: 0.7961 - val_loss: 0.5698 - val_accuracy: 0.8070
# Epoch 165/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5660 - accuracy: 0.7987 - val_loss: 0.5786 - val_accuracy: 0.8079
# Epoch 166/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5676 - accuracy: 0.7963 - val_loss: 0.5780 - val_accuracy: 0.8073
# Epoch 167/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5672 - accuracy: 0.7984 - val_loss: 0.5865 - val_accuracy: 0.8045
# Epoch 168/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5690 - accuracy: 0.7975 - val_loss: 0.5682 - val_accuracy: 0.8065
# Epoch 169/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5724 - accuracy: 0.7969 - val_loss: 0.5852 - val_accuracy: 0.8067
# Epoch 170/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5563 - accuracy: 0.8015 - val_loss: 0.5800 - val_accuracy: 0.8076
# Epoch 171/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5544 - accuracy: 0.8020 - val_loss: 0.5950 - val_accuracy: 0.8021
# Epoch 172/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5785 - accuracy: 0.7959 - val_loss: 0.5814 - val_accuracy: 0.8055
# Epoch 173/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5567 - accuracy: 0.7979 - val_loss: 0.5877 - val_accuracy: 0.8052
# Epoch 174/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5773 - accuracy: 0.7940 - val_loss: 0.5762 - val_accuracy: 0.8088
# Epoch 175/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5605 - accuracy: 0.8000 - val_loss: 0.5921 - val_accuracy: 0.8057
# Epoch 176/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5556 - accuracy: 0.8019 - val_loss: 0.5908 - val_accuracy: 0.8004
# Epoch 177/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5567 - accuracy: 0.7985 - val_loss: 0.5842 - val_accuracy: 0.8064
# Epoch 178/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5431 - accuracy: 0.8066 - val_loss: 0.5795 - val_accuracy: 0.8066
# Epoch 179/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5610 - accuracy: 0.7990 - val_loss: 0.5716 - val_accuracy: 0.8078
# Epoch 180/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5600 - accuracy: 0.7988 - val_loss: 0.5864 - val_accuracy: 0.8067
# Epoch 181/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5658 - accuracy: 0.7977 - val_loss: 0.5792 - val_accuracy: 0.8099
# Epoch 182/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5439 - accuracy: 0.8029 - val_loss: 0.5783 - val_accuracy: 0.8092
# Epoch 183/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5423 - accuracy: 0.8063 - val_loss: 0.5995 - val_accuracy: 0.8044
# Epoch 184/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5500 - accuracy: 0.8035 - val_loss: 0.5655 - val_accuracy: 0.8099
# Epoch 185/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5603 - accuracy: 0.7987 - val_loss: 0.5718 - val_accuracy: 0.8099
# Epoch 186/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5497 - accuracy: 0.8009 - val_loss: 0.5778 - val_accuracy: 0.8104
# Epoch 187/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5495 - accuracy: 0.8047 - val_loss: 0.5841 - val_accuracy: 0.8090
# Epoch 188/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5550 - accuracy: 0.8023 - val_loss: 0.5813 - val_accuracy: 0.8050
# Epoch 189/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5485 - accuracy: 0.8048 - val_loss: 0.5895 - val_accuracy: 0.8050
# Epoch 190/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5564 - accuracy: 0.8013 - val_loss: 0.5893 - val_accuracy: 0.8075
# Epoch 191/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5383 - accuracy: 0.8073 - val_loss: 0.5728 - val_accuracy: 0.8118
# Epoch 192/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5411 - accuracy: 0.8057 - val_loss: 0.5690 - val_accuracy: 0.8109
# Epoch 193/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5371 - accuracy: 0.8084 - val_loss: 0.5886 - val_accuracy: 0.8080
# Epoch 194/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5523 - accuracy: 0.8021 - val_loss: 0.5918 - val_accuracy: 0.8051
# Epoch 195/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5506 - accuracy: 0.8044 - val_loss: 0.5988 - val_accuracy: 0.8050
# Epoch 196/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5718 - accuracy: 0.7989 - val_loss: 0.5768 - val_accuracy: 0.8086
# Epoch 197/200
# 79/79 [==============================] - 3s 35ms/step - loss: 0.5545 - accuracy: 0.7991 - val_loss: 0.5670 - val_accuracy: 0.8132
# Epoch 198/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5413 - accuracy: 0.8030 - val_loss: 0.5783 - val_accuracy: 0.8102
# Epoch 199/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5335 - accuracy: 0.8058 - val_loss: 0.5771 - val_accuracy: 0.8085
# Epoch 200/200
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5482 - accuracy: 0.8056 - val_loss: 0.5680 - val_accuracy: 0.8133

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:09:27.725844

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.804

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_cnn)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
