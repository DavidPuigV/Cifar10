# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/SIX_cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu'))
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 591,274
# Trainable params: 591,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)
# Out:
# '\ncallback_val_loss = EarlyStopping(monitor="val_loss", patience=5)\ncallback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)\n'

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0            # ya cambiamos el escalado a de 0 a 1

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    rotation_range = 5,
    shear_range = 0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    width_shift_range=0.05,
    height_shift_range=0.05,
    brightness_range=(0.5,1.5),
    fill_mode='nearest'
    )

# debemos coger las imagenes originales, le doy la x, le doy la y 
# y el batch size = cuantas imagenes voy a generar por cada paquete, data generation (no podemos pasarnos, misma cantidad que le pasamos en eel data set)
train_generator = train_datagen.flow( 
    x_train, 
    y_train, 
    batch_size=256          # hago esto para cada 30 imagenes
    )
# Out:
# '\ntrain_datagen = ImageDataGenerator( \n    rescale=1./255,\n    rotation_range = 50,\n    shear_range = 0.2,\n    zoom_range=0.3,\n    horizontal_flip=True\n    )\n\n# debemos coger las imagenes originales, le doy la x, le doy la y \n# y el batch size = cuantas imagenes voy a generar por cada paquete, data generation (no podemos pasarnos, misma cantidad que le pasamos en eel data set)\ntrain_generator = train_datagen.flow( \n    x_train_img, \n    y_train_img, \n    batch_size=30          # hago esto para cada 30 imagenes\n    )  \n'

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val, 
    batch_size=256
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test,
    batch_size=256
    )
# Out:
# '\nvalidation_datagen = ImageDataGenerator(\n    rescale=1./255\n    )\nvalidation_generator = validation_datagen.flow(\n    x_val_img, \n    y_val_img, \n    batch_size=20\n    )\n\ntest_datagen = ImageDataGenerator(\n    rescale=1./255\n    )\ntest_generator = test_datagen.flow(\n    x_test_img, \n    y_test_img,\n    batch_size=20\n    )\n'

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

plt.imshow(x_train[sample]/255.)
# Out:
# '\nsample = random.choice(range(0,1450))\nexample_generator = train_datagen.flow(\n    x_train_img[sample:sample+1],\n    y_train_img[sample:sample+1],\n    batch_size=20\n    )\n\nplt.imshow(x_train_img[sample]/255.)\n'

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 79/79 [==============================] - 4s 28ms/step - loss: 2.2834 - accuracy: 0.1263 - val_loss: 1.9670 - val_accuracy: 0.2878
# Epoch 2/200
# 79/79 [==============================] - 2s 22ms/step - loss: 1.9302 - accuracy: 0.2912 - val_loss: 1.6508 - val_accuracy: 0.4110
# Epoch 3/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.7160 - accuracy: 0.3695 - val_loss: 1.5007 - val_accuracy: 0.4607
# Epoch 4/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.5735 - accuracy: 0.4237 - val_loss: 1.4070 - val_accuracy: 0.5025
# Epoch 5/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.4871 - accuracy: 0.4613 - val_loss: 1.3640 - val_accuracy: 0.5255
# Epoch 6/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.4311 - accuracy: 0.4858 - val_loss: 1.2381 - val_accuracy: 0.5570
# Epoch 7/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.3695 - accuracy: 0.5033 - val_loss: 1.2009 - val_accuracy: 0.5631
# Epoch 8/200
# 79/79 [==============================] - 2s 22ms/step - loss: 1.3640 - accuracy: 0.5101 - val_loss: 1.2277 - val_accuracy: 0.5697
# Epoch 9/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.2882 - accuracy: 0.5407 - val_loss: 1.0888 - val_accuracy: 0.6091
# Epoch 10/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.2296 - accuracy: 0.5606 - val_loss: 1.0512 - val_accuracy: 0.6254
# Epoch 11/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.2083 - accuracy: 0.5658 - val_loss: 1.0434 - val_accuracy: 0.6313
# Epoch 12/200
# 79/79 [==============================] - 2s 22ms/step - loss: 1.1781 - accuracy: 0.5791 - val_loss: 1.0203 - val_accuracy: 0.6377
# Epoch 13/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.1509 - accuracy: 0.5886 - val_loss: 0.9655 - val_accuracy: 0.6552
# Epoch 14/200
# 79/79 [==============================] - 2s 21ms/step - loss: 1.1163 - accuracy: 0.6034 - val_loss: 0.9506 - val_accuracy: 0.6667
# Epoch 15/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6057 - accuracy: 0.7852 - val_loss: 0.5430 - val_accuracy: 0.8148
# Epoch 194/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6039 - accuracy: 0.7849 - val_loss: 0.5487 - val_accuracy: 0.8131
# Epoch 195/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6059 - accuracy: 0.7860 - val_loss: 0.5683 - val_accuracy: 0.8088
# Epoch 196/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6071 - accuracy: 0.7856 - val_loss: 0.5549 - val_accuracy: 0.8097
# Epoch 197/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6205 - accuracy: 0.7794 - val_loss: 0.5559 - val_accuracy: 0.8091
# Epoch 198/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6119 - accuracy: 0.7871 - val_loss: 0.5710 - val_accuracy: 0.8021
# Epoch 199/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.6000 - accuracy: 0.7879 - val_loss: 0.6056 - val_accuracy: 0.7963
# Epoch 200/200
# 79/79 [==============================] - 2s 22ms/step - loss: 0.5948 - accuracy: 0.7926 - val_loss: 0.5497 - val_accuracy: 0.8137

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:05:44.140617

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.806

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
