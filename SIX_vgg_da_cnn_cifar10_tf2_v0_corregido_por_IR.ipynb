# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/SIX_vgg_da_cnn_cifar10_tf2_v0_corregido_por_IR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## 1.1. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val= x_train[-10000:]
y_val = y_train[-10000:]

x_train= x_train[:-10000]
y_train = y_train[:-10000]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# # 2. VGG16 Carga de la parte de extraccion de features

# %%
'''
vgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(32,32,3))
vgg.summary()
'''
# Out:
# "\nvgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(32,32,3))\nvgg.summary()\n"

# %%
'''
def_output = vgg.layers[-1].output
new_flatten_layer = ks.layers.Flatten()(def_output)
new_flatten_layer
'''
# Out:
# '\ndef_output = vgg.layers[-1].output\nnew_flatten_layer = ks.layers.Flatten()(def_output)\nnew_flatten_layer\n'

# %%
'''
vgg_model = Model(vgg.input, new_flatten_layer)
vgg_model.summary()
'''
# Out:
# '\nvgg_model = Model(vgg.input, new_flatten_layer)\nvgg_model.summary()\n'

# %%
'''
pd.set_option('max_colwidth', None)                                               # volem congelar els pesos de la xarxa vgg16
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
'''
# Out:
# "\npd.set_option('max_colwidth', None)                                               # volem congelar els pesos de la xarxa vgg16\nlayers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]\npd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])\n"

# %%
'''
print(vgg_model.trainable)
'''
# Out:
# '\nprint(vgg_model.trainable)\n'

# %%
'''
vgg_model.trainable = False

for layer in vgg_model.layers:
  layer.trainable = False
'''
# Out:
# '\nvgg_model.trainable = False\n\nfor layer in vgg_model.layers:\n  layer.trainable = False\n'

# %%
'''
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
'''
# Out:
# "\nlayers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]\npd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])\n"

# %%
'''
# PREPROCESADO DE IMAGENES HASTA EL CUELLO DE BOTELLA

def llevar_cuello_botella(model, input_imgs):
    features = model.predict(input_imgs, verbose=0)
    return features
'''
# Out:
# '\n# PREPROCESADO DE IMAGENES HASTA EL CUELLO DE BOTELLA\n\ndef llevar_cuello_botella(model, input_imgs):\n    features = model.predict(input_imgs, verbose=0)\n    return features\n'

# %%
'''
x_train_post_vgg = llevar_cuello_botella(vgg_model, x_train_scaled)
x_test_post_vgg = llevar_cuello_botella(vgg_model, x_test_scaled)
x_val_post_vgg = llevar_cuello_botella(vgg_model, x_val)
'''
# Out:
# '\nx_train_post_vgg = llevar_cuello_botella(vgg_model, x_train_scaled)\nx_test_post_vgg = llevar_cuello_botella(vgg_model, x_test_scaled)\nx_val_post_vgg = llevar_cuello_botella(vgg_model, x_val)\n'

# %%
'''
x_train_post_vgg.shape
'''
# Out:
# '\nx_train_post_vgg.shape\n'

# %%
'''
# MONTAMOS RED DE CLASIFICACION

input_shape = vgg_model.output_shape[1]
print(input_shape)
'''
# Out:
# '\n# MONTAMOS RED DE CLASIFICACION\n\ninput_shape = vgg_model.output_shape[1]\nprint(input_shape)\n'

# %%
'''
# ARQUITECTURA CON  VGG16

model_post_vgg = ks.Sequential()

model_post_vgg.add(ks.layers.InputLayer(input_shape=(input_shape,)))
model_post_vgg.add(ks.layers.Dense(512, activation='relu', input_shape=(input_shape,)))
model_post_vgg.add(ks.layers.Dropout(0.5))  

model_post_vgg.add(ks.layers.Dense(10, activation='softmax'))
model_post_vgg.summary()
'''
# Out:
# "\n# ARQUITECTURA CON  VGG16\n\nmodel_post_vgg = ks.Sequential()\n\nmodel_post_vgg.add(ks.layers.InputLayer(input_shape=(input_shape,)))\nmodel_post_vgg.add(ks.layers.Dense(512, activation='relu', input_shape=(input_shape,)))\nmodel_post_vgg.add(ks.layers.Dropout(0.5))  \n\nmodel_post_vgg.add(ks.layers.Dense(10, activation='softmax'))\nmodel_post_vgg.summary()\n"

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform',  padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu', kernel_regularizer=l2(0.001),kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,345,066
# Trainable params: 1,343,146
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
# OPTIMIZADOR DEL VGG
# model_post_vgg.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Optimizador Initial y Data Augmentation
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=25)

# %% [markdown]
# # 4. Data Augmentation

# %% [markdown]
# ### Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    horizontal_flip=True,
    # rotation_range = 10,
    # shear_range = 0.1,
    # zoom_range= 0.1,
    # width_shift_range=0.1,
    # height_shift_range=0.1,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=512          # hago esto para cada 30 imagenes
    )

# %% [markdown]
# ### vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=512
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=512
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=512
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# VGG16
# history = model_post_vgg.fit(x_train_post_vgg, y_train, epochs=150, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val_post_vgg, y_val))

# Data Augmentation
history = model.fit(train_generator,epochs=100,steps_per_epoch= 78,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=20)

# Initial
# history = model.fit(x_train, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 78/78 [==============================] - 13s 63ms/step - loss: 4.3903 - accuracy: 0.2570 - val_loss: 5.3158 - val_accuracy: 0.0973
# Epoch 2/100
# 78/78 [==============================] - 4s 54ms/step - loss: 3.4109 - accuracy: 0.4250 - val_loss: 5.0117 - val_accuracy: 0.1400
# Epoch 3/100
# 78/78 [==============================] - 4s 54ms/step - loss: 3.0380 - accuracy: 0.4762 - val_loss: 4.6962 - val_accuracy: 0.1845
# Epoch 4/100
# 78/78 [==============================] - 4s 55ms/step - loss: 2.7013 - accuracy: 0.5220 - val_loss: 4.3063 - val_accuracy: 0.2252
# Epoch 5/100
# 78/78 [==============================] - 4s 55ms/step - loss: 2.4253 - accuracy: 0.5621 - val_loss: 3.1639 - val_accuracy: 0.3157
# Epoch 6/100
# 78/78 [==============================] - 4s 54ms/step - loss: 2.1691 - accuracy: 0.5973 - val_loss: 2.5959 - val_accuracy: 0.4484
# Epoch 7/100
# 78/78 [==============================] - 4s 54ms/step - loss: 1.9798 - accuracy: 0.6196 - val_loss: 2.2401 - val_accuracy: 0.5228
# Epoch 8/100
# 78/78 [==============================] - 4s 54ms/step - loss: 1.7989 - accuracy: 0.6518 - val_loss: 1.9374 - val_accuracy: 0.5862
# Epoch 9/100
# 78/78 [==============================] - 4s 55ms/step - loss: 1.6562 - accuracy: 0.6703 - val_loss: 1.9240 - val_accuracy: 0.5656
# Epoch 10/100
# 78/78 [==============================] - 4s 55ms/step - loss: 1.5519 - accuracy: 0.6874 - val_loss: 1.6875 - val_accuracy: 0.6206
# Epoch 11/100
# 78/78 [==============================] - 4s 55ms/step - loss: 1.4557 - accuracy: 0.7063 - val_loss: 1.6195 - val_accuracy: 0.6337
# Epoch 12/100
# 78/78 [==============================] - 4s 55ms/step - loss: 1.3729 - accuracy: 0.7192 - val_loss: 1.3993 - val_accuracy: 0.6972
# Epoch 13/100
# 78/78 [==============================] - 4s 55ms/step - loss: 1.3060 - accuracy: 0.7286 - val_loss: 1.3005 - val_accuracy: 0.7266
# Epoch 14/100
# 78/78 [==============================] - 4s 56ms/step - loss: 1.2566 - accuracy: 0.7389 - val_loss: 1.2060 - val_accuracy: 0.7485
# Epoch 15/100
# 78/78 [==============================] - 4s 56ms/step - loss: 1.2073 - accuracy: 0.7483 - val_loss: 1.2580 - val_accuracy: 0.7196
# Epoch 16/100
# 78/78 [==============================] - 4s 56ms/step - loss: 1.1640 - accuracy: 0.7535 - val_loss: 1.2794 - val_accuracy: 0.7164
# Epoch 17/100
# 78/78 [==============================] - 4s 56ms/step - loss: 1.1273 - accuracy: 0.7652 - val_loss: 1.0902 - val_accuracy: 0.7788
# Epoch 18/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0981 - accuracy: 0.7715 - val_loss: 1.1240 - val_accuracy: 0.7629
# Epoch 19/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0947 - accuracy: 0.7737 - val_loss: 1.1249 - val_accuracy: 0.7620
# Epoch 20/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0639 - accuracy: 0.7813 - val_loss: 1.1062 - val_accuracy: 0.7739
# Epoch 21/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0440 - accuracy: 0.7879 - val_loss: 1.0553 - val_accuracy: 0.7830
# Epoch 22/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0261 - accuracy: 0.7881 - val_loss: 1.0455 - val_accuracy: 0.7827
# Epoch 23/100
# 78/78 [==============================] - 5s 58ms/step - loss: 1.0119 - accuracy: 0.7932 - val_loss: 0.9833 - val_accuracy: 0.8014
# Epoch 24/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0017 - accuracy: 0.7922 - val_loss: 0.9748 - val_accuracy: 0.8061
# Epoch 25/100
# 78/78 [==============================] - 5s 58ms/step - loss: 1.0052 - accuracy: 0.7919 - val_loss: 1.0411 - val_accuracy: 0.7853
# Epoch 26/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9822 - accuracy: 0.8027 - val_loss: 0.9726 - val_accuracy: 0.8043
# Epoch 27/100
# 78/78 [==============================] - 4s 57ms/step - loss: 1.0036 - accuracy: 0.7930 - val_loss: 0.9108 - val_accuracy: 0.8265
# Epoch 28/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9609 - accuracy: 0.8064 - val_loss: 0.9353 - val_accuracy: 0.8200
# Epoch 29/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9563 - accuracy: 0.8091 - val_loss: 0.9121 - val_accuracy: 0.8285
# Epoch 30/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9534 - accuracy: 0.8069 - val_loss: 0.9474 - val_accuracy: 0.8122
# Epoch 31/100
# 78/78 [==============================] - 5s 59ms/step - loss: 0.9635 - accuracy: 0.8053 - val_loss: 0.9835 - val_accuracy: 0.8031
# Epoch 32/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9450 - accuracy: 0.8128 - val_loss: 1.0151 - val_accuracy: 0.7903
# Epoch 33/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9333 - accuracy: 0.8142 - val_loss: 0.9376 - val_accuracy: 0.8187
# Epoch 34/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9632 - accuracy: 0.8094 - val_loss: 0.8729 - val_accuracy: 0.8407
# Epoch 35/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9386 - accuracy: 0.8129 - val_loss: 0.9012 - val_accuracy: 0.8242
# Epoch 36/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9502 - accuracy: 0.8106 - val_loss: 0.9419 - val_accuracy: 0.8160
# Epoch 37/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9159 - accuracy: 0.8222 - val_loss: 0.9029 - val_accuracy: 0.8268
# Epoch 38/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9304 - accuracy: 0.8184 - val_loss: 0.9028 - val_accuracy: 0.8312
# Epoch 39/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.9216 - accuracy: 0.8202 - val_loss: 0.9268 - val_accuracy: 0.8186
# Epoch 40/100
# 78/78 [==============================] - 4s 58ms/step - loss: 0.9038 - accuracy: 0.8242 - val_loss: 0.8801 - val_accuracy: 0.8373
# Epoch 41/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.9169 - accuracy: 0.8202 - val_loss: 0.8970 - val_accuracy: 0.8324
# Epoch 42/100
# 78/78 [==============================] - 4s 58ms/step - loss: 0.9059 - accuracy: 0.8233 - val_loss: 0.9232 - val_accuracy: 0.8187
# Epoch 43/100
# 78/78 [==============================] - 4s 58ms/step - loss: 0.8954 - accuracy: 0.8258 - val_loss: 0.8952 - val_accuracy: 0.8304
# Epoch 44/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8877 - accuracy: 0.8266 - val_loss: 0.9257 - val_accuracy: 0.8238
# Epoch 45/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8835 - accuracy: 0.8305 - val_loss: 0.8660 - val_accuracy: 0.8376
# Epoch 46/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8850 - accuracy: 0.8301 - val_loss: 0.8716 - val_accuracy: 0.8370
# Epoch 47/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8826 - accuracy: 0.8307 - val_loss: 0.8631 - val_accuracy: 0.8367
# Epoch 48/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8799 - accuracy: 0.8256 - val_loss: 0.8941 - val_accuracy: 0.8285
# Epoch 49/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8762 - accuracy: 0.8299 - val_loss: 0.8967 - val_accuracy: 0.8233
# Epoch 50/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8998 - accuracy: 0.8235 - val_loss: 0.8459 - val_accuracy: 0.8522
# Epoch 51/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8761 - accuracy: 0.8338 - val_loss: 0.8458 - val_accuracy: 0.8455
# Epoch 52/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8666 - accuracy: 0.8354 - val_loss: 0.8256 - val_accuracy: 0.8533
# Epoch 53/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8750 - accuracy: 0.8341 - val_loss: 0.9570 - val_accuracy: 0.8126
# Epoch 54/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8701 - accuracy: 0.8348 - val_loss: 0.8680 - val_accuracy: 0.8334
# Epoch 55/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8767 - accuracy: 0.8290 - val_loss: 0.8619 - val_accuracy: 0.8402
# Epoch 56/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8491 - accuracy: 0.8386 - val_loss: 0.8534 - val_accuracy: 0.8440
# Epoch 57/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8488 - accuracy: 0.8390 - val_loss: 0.8938 - val_accuracy: 0.8315
# Epoch 58/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8485 - accuracy: 0.8369 - val_loss: 0.8704 - val_accuracy: 0.8349
# Epoch 59/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8701 - accuracy: 0.8329 - val_loss: 0.9208 - val_accuracy: 0.8222
# Epoch 60/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8842 - accuracy: 0.8321 - val_loss: 0.9279 - val_accuracy: 0.8215
# Epoch 61/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8509 - accuracy: 0.8396 - val_loss: 0.8486 - val_accuracy: 0.8474
# Epoch 62/100
# 78/78 [==============================] - 5s 57ms/step - loss: 0.8446 - accuracy: 0.8401 - val_loss: 0.8386 - val_accuracy: 0.8489
# Epoch 63/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8558 - accuracy: 0.8354 - val_loss: 0.8608 - val_accuracy: 0.8332
# Epoch 64/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8389 - accuracy: 0.8413 - val_loss: 0.8700 - val_accuracy: 0.8313
# Epoch 65/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8649 - accuracy: 0.8334 - val_loss: 0.8398 - val_accuracy: 0.8474
# Epoch 66/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8510 - accuracy: 0.8383 - val_loss: 0.8331 - val_accuracy: 0.8499
# Epoch 67/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8525 - accuracy: 0.8367 - val_loss: 0.8315 - val_accuracy: 0.8506
# Epoch 68/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8537 - accuracy: 0.8387 - val_loss: 0.8199 - val_accuracy: 0.8527
# Epoch 69/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8509 - accuracy: 0.8369 - val_loss: 0.8445 - val_accuracy: 0.8479
# Epoch 70/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8493 - accuracy: 0.8384 - val_loss: 0.8796 - val_accuracy: 0.8394
# Epoch 71/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8440 - accuracy: 0.8399 - val_loss: 0.8720 - val_accuracy: 0.8365
# Epoch 72/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8261 - accuracy: 0.8486 - val_loss: 0.8605 - val_accuracy: 0.8368
# Epoch 73/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8215 - accuracy: 0.8470 - val_loss: 0.9682 - val_accuracy: 0.8148
# Epoch 74/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8582 - accuracy: 0.8348 - val_loss: 0.8477 - val_accuracy: 0.8459
# Epoch 75/100
# 78/78 [==============================] - 4s 57ms/step - loss: 0.8346 - accuracy: 0.8453 - val_loss: 0.8211 - val_accuracy: 0.8495
# Epoch 76/100
# 78/78 [==============================] - 4s 58ms/step - loss: 0.8295 - accuracy: 0.8446 - val_loss: 0.8463 - val_accuracy: 0.8423
# Epoch 77/100
# 78/78 [==============================] - 5s 58ms/step - loss: 0.8440 - accuracy: 0.8412 - val_loss: 0.8170 - val_accuracy: 0.8498

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:05:52.582016

# %% [markdown]
# ## 6. Evaluamos el Modelo

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.849

# %%
# Initial
# model.evaluate(x_test, y_test, verbose=0)

# for Data Agumentation
# model.evaluate(x_test, y_test, verbose=0)

# for VGG16
# model_post_vgg.evaluate(x_test, y_test, verbose=0)

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
