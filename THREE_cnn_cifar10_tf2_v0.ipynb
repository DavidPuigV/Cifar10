# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/THREE_cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 84,362
# Trainable params: 84,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=5)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
x_train_cnn = x_train.reshape((x_train.shape[0], 32, 32, 3))
x_test_cnn = x_test.reshape((x_test.shape[0], 32, 32, 3))
x_val_cnn = x_val.reshape((x_val.shape[0],32,32,3))

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_cnn.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_cnn.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_cnn.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_cnn, y_train, epochs=200, use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 79/79 [==============================] - 10s 33ms/step - loss: 2.2234 - accuracy: 0.1495 - val_loss: 1.8587 - val_accuracy: 0.2945
# Epoch 2/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.8549 - accuracy: 0.3051 - val_loss: 1.5957 - val_accuracy: 0.4133
# Epoch 3/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.6823 - accuracy: 0.3731 - val_loss: 1.4520 - val_accuracy: 0.4802
# Epoch 4/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.5588 - accuracy: 0.4242 - val_loss: 1.4173 - val_accuracy: 0.4874
# Epoch 5/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.4786 - accuracy: 0.4586 - val_loss: 1.2917 - val_accuracy: 0.5484
# Epoch 6/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.4031 - accuracy: 0.4854 - val_loss: 1.2870 - val_accuracy: 0.5380
# Epoch 7/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.3876 - accuracy: 0.5010 - val_loss: 1.2213 - val_accuracy: 0.5662
# Epoch 8/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.3118 - accuracy: 0.5308 - val_loss: 1.1803 - val_accuracy: 0.5878
# Epoch 9/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.2687 - accuracy: 0.5399 - val_loss: 1.1271 - val_accuracy: 0.6035
# Epoch 10/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.2498 - accuracy: 0.5527 - val_loss: 1.1212 - val_accuracy: 0.5996
# Epoch 11/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.2344 - accuracy: 0.5566 - val_loss: 1.0633 - val_accuracy: 0.6285
# Epoch 12/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.1924 - accuracy: 0.5771 - val_loss: 1.0197 - val_accuracy: 0.6407
# Epoch 13/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.1727 - accuracy: 0.5843 - val_loss: 0.9899 - val_accuracy: 0.6515
# Epoch 14/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1.1413 - accuracy: 0.5954 - val_loss: 0.9693 - val_accuracy: 0.6629
# Epoch 15/200
# 79/79 [==============================] - 2s 26ms/step - loss: 1
200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6028 - accuracy: 0.7903 - val_loss: 0.6277 - val_accuracy: 0.7896
# Epoch 102/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6152 - accuracy: 0.7882 - val_loss: 0.5992 - val_accuracy: 0.7964
# Epoch 103/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6191 - accuracy: 0.7838 - val_loss: 0.6010 - val_accuracy: 0.7969
# Epoch 104/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6164 - accuracy: 0.7827 - val_loss: 0.6040 - val_accuracy: 0.7919
# Epoch 105/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5951 - accuracy: 0.7931 - val_loss: 0.5864 - val_accuracy: 0.8001
# Epoch 106/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6069 - accuracy: 0.7902 - val_loss: 0.5901 - val_accuracy: 0.7988
# Epoch 107/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5959 - accuracy: 0.7893 - val_loss: 0.5913 - val_accuracy: 0.7977
# Epoch 108/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5904 - accuracy: 0.7930 - val_loss: 0.5897 - val_accuracy: 0.8006
# Epoch 109/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6033 - accuracy: 0.7899 - val_loss: 0.5798 - val_accuracy: 0.8029
# Epoch 110/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6196 - accuracy: 0.7843 - val_loss: 0.5802 - val_accuracy: 0.8033
# Epoch 111/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5865 - accuracy: 0.7945 - val_loss: 0.5796 - val_accuracy: 0.7993
# Epoch 112/200
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5898 - accuracy: 0.7945 - val_loss: 0.5920 - val_accuracy: 0.7999
# Epoch 113/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5941 - accuracy: 0.7936 - val_loss: 0.5868 - val_accuracy: 0.8028
# Epoch 114/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.6009 - accuracy: 0.7904 - val_loss: 0.6052 - val_accuracy: 0.7956
# Epoch 115/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5992 - accuracy: 0.7897 - val_loss: 0.6022 - val_accuracy: 0.7976
# Epoch 116/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5957 - accuracy: 0.7908 - val_loss: 0.5901 - val_accuracy: 0.8015
# Epoch 117/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5730 - accuracy: 0.8000 - val_loss: 0.5837 - val_accuracy: 0.8003
# Epoch 118/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5789 - accuracy: 0.7961 - val_loss: 0.5687 - val_accuracy: 0.8077
# Epoch 119/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5905 - accuracy: 0.7940 - val_loss: 0.5865 - val_accuracy: 0.8028
# Epoch 120/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5787 - accuracy: 0.7957 - val_loss: 0.5968 - val_accuracy: 0.7978
# Epoch 121/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5906 - accuracy: 0.7951 - val_loss: 0.5860 - val_accuracy: 0.8031
# Epoch 122/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5731 - accuracy: 0.8033 - val_loss: 0.5741 - val_accuracy: 0.8080
# Epoch 123/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5800 - accuracy: 0.7951 - val_loss: 0.5845 - val_accuracy: 0.8043
# Epoch 124/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5791 - accuracy: 0.7957 - val_loss: 0.5915 - val_accuracy: 0.8011
# Epoch 125/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5726 - accuracy: 0.8010 - val_loss: 0.5797 - val_accuracy: 0.8066
# Epoch 126/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5622 - accuracy: 0.8033 - val_loss: 0.5789 - val_accuracy: 0.8049
# Epoch 127/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5641 - accuracy: 0.8028 - val_loss: 0.5836 - val_accuracy: 0.8030
# Epoch 128/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5710 - accuracy: 0.8002 - val_loss: 0.5794 - val_accuracy: 0.8065
# Epoch 129/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5724 - accuracy: 0.7977 - val_loss: 0.5889 - val_accuracy: 0.7985
# Epoch 130/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5641 - accuracy: 0.8031 - val_loss: 0.5857 - val_accuracy: 0.8046
# Epoch 131/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5571 - accuracy: 0.8076 - val_loss: 0.5795 - val_accuracy: 0.8076
# Epoch 132/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5756 - accuracy: 0.7973 - val_loss: 0.5962 - val_accuracy: 0.8030
# Epoch 133/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5830 - accuracy: 0.7980 - val_loss: 0.5904 - val_accuracy: 0.8040
# Epoch 134/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5717 - accuracy: 0.7994 - val_loss: 0.5895 - val_accuracy: 0.8048
# Epoch 135/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5701 - accuracy: 0.8039 - val_loss: 0.5816 - val_accuracy: 0.8054
# Epoch 136/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5648 - accuracy: 0.8034 - val_loss: 0.5960 - val_accuracy: 0.7996
# Epoch 137/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5622 - accuracy: 0.8041 - val_loss: 0.5777 - val_accuracy: 0.8068
# Epoch 138/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5551 - accuracy: 0.8104 - val_loss: 0.5730 - val_accuracy: 0.8070
# Epoch 139/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5585 - accuracy: 0.8044 - val_loss: 0.5741 - val_accuracy: 0.8020
# Epoch 140/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5665 - accuracy: 0.8012 - val_loss: 0.6023 - val_accuracy: 0.8028
# Epoch 141/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5660 - accuracy: 0.8006 - val_loss: 0.5789 - val_accuracy: 0.8045
# Epoch 142/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5471 - accuracy: 0.8077 - val_loss: 0.5916 - val_accuracy: 0.8029
# Epoch 143/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5644 - accuracy: 0.8037 - val_loss: 0.5683 - val_accuracy: 0.8116
# Epoch 144/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5509 - accuracy: 0.8098 - val_loss: 0.5698 - val_accuracy: 0.8071
# Epoch 145/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5541 - accuracy: 0.8076 - val_loss: 0.5820 - val_accuracy: 0.8082
# Epoch 146/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5572 - accuracy: 0.8067 - val_loss: 0.5882 - val_accuracy: 0.8072
# Epoch 147/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5577 - accuracy: 0.8046 - val_loss: 0.5747 - val_accuracy: 0.8086
# Epoch 148/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5535 - accuracy: 0.8078 - val_loss: 0.5927 - val_accuracy: 0.8023
# Epoch 149/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5527 - accuracy: 0.8078 - val_loss: 0.5678 - val_accuracy: 0.8126
# Epoch 150/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5437 - accuracy: 0.8136 - val_loss: 0.5676 - val_accuracy: 0.8074
# Epoch 151/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5410 - accuracy: 0.8118 - val_loss: 0.5932 - val_accuracy: 0.8032
# Epoch 152/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5434 - accuracy: 0.8089 - val_loss: 0.5889 - val_accuracy: 0.8038
# Epoch 153/200
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5494 - accuracy: 0.8074 - val_loss: 0.5690 - val_accuracy: 0.8116
# Epoch 154/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5385 - accuracy: 0.8135 - val_loss: 0.5849 - val_accuracy: 0.8052
# Epoch 155/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5438 - accuracy: 0.8109 - val_loss: 0.5891 - val_accuracy: 0.7988
# Epoch 156/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5519 - accuracy: 0.8091 - val_loss: 0.5865 - val_accuracy: 0.8022
# Epoch 157/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5510 - accuracy: 0.8131 - val_loss: 0.5783 - val_accuracy: 0.8071
# Epoch 158/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5411 - accuracy: 0.8121 - val_loss: 0.6013 - val_accuracy: 0.8013
# Epoch 159/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5354 - accuracy: 0.8125 - val_loss: 0.5721 - val_accuracy: 0.8096
# Epoch 160/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5312 - accuracy: 0.8145 - val_loss: 0.5803 - val_accuracy: 0.8069
# Epoch 161/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5470 - accuracy: 0.8076 - val_loss: 0.5735 - val_accuracy: 0.8086
# Epoch 162/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5425 - accuracy: 0.8125 - val_loss: 0.5784 - val_accuracy: 0.8074
# Epoch 163/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5430 - accuracy: 0.8144 - val_loss: 0.5835 - val_accuracy: 0.8051
# Epoch 164/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5288 - accuracy: 0.8168 - val_loss: 0.5852 - val_accuracy: 0.8034
# Epoch 165/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5351 - accuracy: 0.8160 - val_loss: 0.5801 - val_accuracy: 0.8067
# Epoch 166/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5353 - accuracy: 0.8149 - val_loss: 0.5841 - val_accuracy: 0.8032
# Epoch 167/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5365 - accuracy: 0.8141 - val_loss: 0.5920 - val_accuracy: 0.8037
# Epoch 168/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5245 - accuracy: 0.8193 - val_loss: 0.5888 - val_accuracy: 0.8037
# Epoch 169/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5303 - accuracy: 0.8150 - val_loss: 0.5870 - val_accuracy: 0.8054
# Epoch 170/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5294 - accuracy: 0.8139 - val_loss: 0.5748 - val_accuracy: 0.8083
# Epoch 171/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5338 - accuracy: 0.8118 - val_loss: 0.5894 - val_accuracy: 0.8054
# Epoch 172/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5271 - accuracy: 0.8161 - val_loss: 0.5803 - val_accuracy: 0.8084
# Epoch 173/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5299 - accuracy: 0.8149 - val_loss: 0.5659 - val_accuracy: 0.8124
# Epoch 174/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5193 - accuracy: 0.8189 - val_loss: 0.5916 - val_accuracy: 0.8036
# Epoch 175/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5280 - accuracy: 0.8165 - val_loss: 0.5831 - val_accuracy: 0.8050
# Epoch 176/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5181 - accuracy: 0.8183 - val_loss: 0.5795 - val_accuracy: 0.8092
# Epoch 177/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5191 - accuracy: 0.8188 - val_loss: 0.5930 - val_accuracy: 0.8015
# Epoch 178/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5404 - accuracy: 0.8116 - val_loss: 0.5823 - val_accuracy: 0.8050
# Epoch 179/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5147 - accuracy: 0.8230 - val_loss: 0.5772 - val_accuracy: 0.8067
# Epoch 180/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5292 - accuracy: 0.8157 - val_loss: 0.5912 - val_accuracy: 0.8042
# Epoch 181/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5222 - accuracy: 0.8161 - val_loss: 0.5651 - val_accuracy: 0.8126
# Epoch 182/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5185 - accuracy: 0.8175 - val_loss: 0.5886 - val_accuracy: 0.8054
# Epoch 183/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5383 - accuracy: 0.8130 - val_loss: 0.5842 - val_accuracy: 0.8065
# Epoch 184/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5267 - accuracy: 0.8188 - val_loss: 0.5696 - val_accuracy: 0.8091
# Epoch 185/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5223 - accuracy: 0.8187 - val_loss: 0.5695 - val_accuracy: 0.8128
# Epoch 186/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5120 - accuracy: 0.8231 - val_loss: 0.5824 - val_accuracy: 0.8074
# Epoch 187/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5241 - accuracy: 0.8158 - val_loss: 0.5995 - val_accuracy: 0.8033
# Epoch 188/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5210 - accuracy: 0.8188 - val_loss: 0.5821 - val_accuracy: 0.8053
# Epoch 189/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5147 - accuracy: 0.8217 - val_loss: 0.5792 - val_accuracy: 0.8089
# Epoch 190/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5067 - accuracy: 0.8251 - val_loss: 0.5692 - val_accuracy: 0.8097
# Epoch 191/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5102 - accuracy: 0.8213 - val_loss: 0.5865 - val_accuracy: 0.8081
# Epoch 192/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5008 - accuracy: 0.8235 - val_loss: 0.5746 - val_accuracy: 0.8088
# Epoch 193/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5163 - accuracy: 0.8192 - val_loss: 0.5751 - val_accuracy: 0.8093
# Epoch 194/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5144 - accuracy: 0.8211 - val_loss: 0.5696 - val_accuracy: 0.8113
# Epoch 195/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5066 - accuracy: 0.8227 - val_loss: 0.5716 - val_accuracy: 0.8097
# Epoch 196/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5047 - accuracy: 0.8265 - val_loss: 0.5630 - val_accuracy: 0.8112
# Epoch 197/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5142 - accuracy: 0.8200 - val_loss: 0.5712 - val_accuracy: 0.8132
# Epoch 198/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5166 - accuracy: 0.8185 - val_loss: 0.5828 - val_accuracy: 0.8088
# Epoch 199/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5043 - accuracy: 0.8237 - val_loss: 0.5613 - val_accuracy: 0.8099
# Epoch 200/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5078 - accuracy: 0.8223 - val_loss: 0.5788 - val_accuracy: 0.8084

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:21.213871

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.812

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_cnn)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
