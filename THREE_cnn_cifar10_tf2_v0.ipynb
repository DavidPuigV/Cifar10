# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidPuigV/Cifar10/blob/main/THREE_cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((3, 3)))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(32, activation='relu'))
model.add(ks.layers.Dropout(0.3))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 84,362
# Trainable params: 84,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=5)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
x_train_cnn = x_train.reshape((x_train.shape[0], 32, 32, 3))
x_test_cnn = x_test.reshape((x_test.shape[0], 32, 32, 3))
x_val_cnn = x_val.reshape((x_val.shape[0],32,32,3))

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_cnn.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_cnn.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_cnn.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_cnn, y_train, epochs=200, use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 79/79 [==============================] - 10s 35ms/step - loss: 2.2229 - accuracy: 0.1530 - val_loss: 1.8569 - val_accuracy: 0.3259
# Epoch 2/200
# 79/79 [==============================] - 2s 27ms/step - loss: 1.8396 - accuracy: 0.3189 - val_loss: 1.6096 - val_accuracy: 0.3981
# Epoch 3/200
# 79/79 [==============================] - 2s 27ms/step - loss: 1.6526 - accuracy: 0.3839 - val_loss: 1.4383 - val_accuracy: 0.4840
# Epoch 4/200
# 79/79 [==============================] - 2s 28ms/step - loss: 1.5609 - accuracy: 0.4265 - val_loss: 1.3744 - val_accuracy: 0.5089
# Epoch 5/200
# 79/79 [==============================] - 2s 27ms/step - loss: 1.4746 - accuracy: 0.4593 - val_loss: 1.3255 - val_accuracy: 0.5242
# Epoch 6/200
# 79/79 [==============================] - 2s 27ms/step - loss: 1.4138 - accuracy: 0.4859 - val_loss: 1.2396 - val_accuracy: 0.5637
# Epoch 7/200
# 79/79 [==============================] - 2s 27ms/step - loss: 1.3621 - accuracy: 0.5079 - val_loss: 1.1816 - val_accuracy: 0.5877
# Epoch 8/200
# 79/79 [==============================] - 2s 28ms/step - loss: 1.3215 - accuracy: 0.5261 - val_loss: 1.1888 - val_accuracy: 0.5846
# Epoch 9/200
# 79/79 [==============================] - 2s 28ms/step - loss: 1.2934 - accuracy: 0.5390 - val_loss: 1.1162 - val_accuracy: 0.6089
# Epoch 10/200
# 79/79 [==============================] - 2s 28ms/step - loss: 1.2368 - accuracy: 0.5547 - val_loss: 1.0739 - val_accuracy: 0.6199
# Epoch 11/200
200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6277 - accuracy: 0.7818 - val_loss: 0.5936 - val_accuracy: 0.7983
# Epoch 98/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6181 - accuracy: 0.7832 - val_loss: 0.6027 - val_accuracy: 0.7970
# Epoch 99/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6205 - accuracy: 0.7829 - val_loss: 0.6148 - val_accuracy: 0.7927
# Epoch 100/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6178 - accuracy: 0.7860 - val_loss: 0.6004 - val_accuracy: 0.7990
# Epoch 101/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5966 - accuracy: 0.7910 - val_loss: 0.5934 - val_accuracy: 0.7988
# Epoch 102/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6057 - accuracy: 0.7903 - val_loss: 0.6298 - val_accuracy: 0.7899
# Epoch 103/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6277 - accuracy: 0.7841 - val_loss: 0.5908 - val_accuracy: 0.7982
# Epoch 104/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6066 - accuracy: 0.7898 - val_loss: 0.5848 - val_accuracy: 0.8007
# Epoch 105/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6059 - accuracy: 0.7881 - val_loss: 0.5985 - val_accuracy: 0.7998
# Epoch 106/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6079 - accuracy: 0.7894 - val_loss: 0.6009 - val_accuracy: 0.7965
# Epoch 107/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6003 - accuracy: 0.7930 - val_loss: 0.6042 - val_accuracy: 0.7927
# Epoch 108/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6125 - accuracy: 0.7895 - val_loss: 0.5912 - val_accuracy: 0.8017
# Epoch 109/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5884 - accuracy: 0.7919 - val_loss: 0.6004 - val_accuracy: 0.7949
# Epoch 110/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5901 - accuracy: 0.7980 - val_loss: 0.5931 - val_accuracy: 0.7999
# Epoch 111/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5955 - accuracy: 0.7929 - val_loss: 0.5880 - val_accuracy: 0.8033
# Epoch 112/200
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5924 - accuracy: 0.7916 - val_loss: 0.5947 - val_accuracy: 0.7953
# Epoch 113/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5832 - accuracy: 0.7966 - val_loss: 0.5969 - val_accuracy: 0.7992
# Epoch 114/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5952 - accuracy: 0.7941 - val_loss: 0.5891 - val_accuracy: 0.8003
# Epoch 115/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5752 - accuracy: 0.8005 - val_loss: 0.5889 - val_accuracy: 0.8035
# Epoch 116/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5923 - accuracy: 0.7930 - val_loss: 0.6028 - val_accuracy: 0.7968
# Epoch 117/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5934 - accuracy: 0.7965 - val_loss: 0.5891 - val_accuracy: 0.8012
# Epoch 118/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6050 - accuracy: 0.7911 - val_loss: 0.5888 - val_accuracy: 0.8025
# Epoch 119/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5858 - accuracy: 0.7971 - val_loss: 0.5849 - val_accuracy: 0.8029
# Epoch 120/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5772 - accuracy: 0.7999 - val_loss: 0.5989 - val_accuracy: 0.7990
# Epoch 121/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5795 - accuracy: 0.7982 - val_loss: 0.5937 - val_accuracy: 0.8020
# Epoch 122/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5786 - accuracy: 0.7987 - val_loss: 0.5948 - val_accuracy: 0.7989
# Epoch 123/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5933 - accuracy: 0.7946 - val_loss: 0.5865 - val_accuracy: 0.8010
# Epoch 124/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5664 - accuracy: 0.8044 - val_loss: 0.5856 - val_accuracy: 0.8071
# Epoch 125/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5797 - accuracy: 0.7984 - val_loss: 0.5873 - val_accuracy: 0.8031
# Epoch 126/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5823 - accuracy: 0.7975 - val_loss: 0.6088 - val_accuracy: 0.7955
# Epoch 127/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5805 - accuracy: 0.7981 - val_loss: 0.5862 - val_accuracy: 0.8034
# Epoch 128/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5649 - accuracy: 0.8015 - val_loss: 0.5935 - val_accuracy: 0.8004
# Epoch 129/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5758 - accuracy: 0.7984 - val_loss: 0.5997 - val_accuracy: 0.7975
# Epoch 130/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5740 - accuracy: 0.7997 - val_loss: 0.5865 - val_accuracy: 0.8045
# Epoch 131/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5896 - accuracy: 0.7949 - val_loss: 0.5767 - val_accuracy: 0.8053
# Epoch 132/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5785 - accuracy: 0.7985 - val_loss: 0.5911 - val_accuracy: 0.7999
# Epoch 133/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5649 - accuracy: 0.8031 - val_loss: 0.5860 - val_accuracy: 0.8015
# Epoch 134/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5577 - accuracy: 0.8039 - val_loss: 0.5994 - val_accuracy: 0.7976
# Epoch 135/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5637 - accuracy: 0.8058 - val_loss: 0.6017 - val_accuracy: 0.7966
# Epoch 136/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5651 - accuracy: 0.8027 - val_loss: 0.5947 - val_accuracy: 0.7994
# Epoch 137/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5607 - accuracy: 0.8054 - val_loss: 0.5959 - val_accuracy: 0.8038
# Epoch 138/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5695 - accuracy: 0.8029 - val_loss: 0.5796 - val_accuracy: 0.8052
# Epoch 139/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5624 - accuracy: 0.8037 - val_loss: 0.5915 - val_accuracy: 0.8020
# Epoch 140/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5531 - accuracy: 0.8087 - val_loss: 0.5882 - val_accuracy: 0.8014
# Epoch 141/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5422 - accuracy: 0.8135 - val_loss: 0.5757 - val_accuracy: 0.8068
# Epoch 142/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5535 - accuracy: 0.8096 - val_loss: 0.6017 - val_accuracy: 0.7989
# Epoch 143/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5439 - accuracy: 0.8115 - val_loss: 0.5887 - val_accuracy: 0.8049
# Epoch 144/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5543 - accuracy: 0.8060 - val_loss: 0.5926 - val_accuracy: 0.8021
# Epoch 145/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5616 - accuracy: 0.8066 - val_loss: 0.6213 - val_accuracy: 0.7941
# Epoch 146/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5508 - accuracy: 0.8077 - val_loss: 0.5971 - val_accuracy: 0.8009
# Epoch 147/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5569 - accuracy: 0.8056 - val_loss: 0.5726 - val_accuracy: 0.8075
# Epoch 148/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5477 - accuracy: 0.8080 - val_loss: 0.5746 - val_accuracy: 0.8099
# Epoch 149/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5422 - accuracy: 0.8125 - val_loss: 0.5803 - val_accuracy: 0.8031
# Epoch 150/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5458 - accuracy: 0.8082 - val_loss: 0.5806 - val_accuracy: 0.8059
# Epoch 151/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5471 - accuracy: 0.8112 - val_loss: 0.5726 - val_accuracy: 0.8093
# Epoch 152/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5516 - accuracy: 0.8103 - val_loss: 0.5936 - val_accuracy: 0.8046
# Epoch 153/200
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5510 - accuracy: 0.8098 - val_loss: 0.5797 - val_accuracy: 0.8086
# Epoch 154/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5517 - accuracy: 0.8095 - val_loss: 0.5784 - val_accuracy: 0.8066
# Epoch 155/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5386 - accuracy: 0.8144 - val_loss: 0.5745 - val_accuracy: 0.8046
# Epoch 156/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5327 - accuracy: 0.8162 - val_loss: 0.6022 - val_accuracy: 0.8001
# Epoch 157/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5463 - accuracy: 0.8096 - val_loss: 0.5645 - val_accuracy: 0.8109
# Epoch 158/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5402 - accuracy: 0.8100 - val_loss: 0.5689 - val_accuracy: 0.8109
# Epoch 159/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.
200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5367 - accuracy: 0.8122 - val_loss: 0.5684 - val_accuracy: 0.8111
# Epoch 191/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5164 - accuracy: 0.8185 - val_loss: 0.5688 - val_accuracy: 0.8117
# Epoch 192/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5108 - accuracy: 0.8193 - val_loss: 0.5993 - val_accuracy: 0.8006
# Epoch 193/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5215 - accuracy: 0.8183 - val_loss: 0.5729 - val_accuracy: 0.8083
# Epoch 194/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5349 - accuracy: 0.8167 - val_loss: 0.5799 - val_accuracy: 0.8104
# Epoch 195/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5178 - accuracy: 0.8179 - val_loss: 0.5967 - val_accuracy: 0.8056
# Epoch 196/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5174 - accuracy: 0.8179 - val_loss: 0.5726 - val_accuracy: 0.8124
# Epoch 197/200
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5046 - accuracy: 0.8250 - val_loss: 0.5772 - val_accuracy: 0.8088
# Epoch 198/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5135 - accuracy: 0.8188 - val_loss: 0.5829 - val_accuracy: 0.8059
# Epoch 199/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5027 - accuracy: 0.8237 - val_loss: 0.5694 - val_accuracy: 0.8056
# Epoch 200/200
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5205 - accuracy: 0.8202 - val_loss: 0.5621 - val_accuracy: 0.8127

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:07:27.262209

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.809

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_cnn)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
